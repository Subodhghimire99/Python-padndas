# %%
import math
import pandas as pd

# %%
df = pd.read_csv("fifa_players_data.csv", nrows=10)[["Name","Age","Nationality","Overall"]]

# %%
# df1 = pd.read_csv("fifa_players_data.csv",nrows=10,header=None)[[0,1,2,3,4]]
#header is None ...it creates new header of index as shown below

# df1 = pd.read_csv("fifa_players_data.csv",nrows=10)[["Name", "Age", "Potential", "Club", "Overall"]]

# we can also supply header as shown below
df1 = pd.read_csv("fifa_players_data.csv",nrows=10,header=None,names=["Name","Age"])

df1.head()
# print(df1.dtypes)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Name  \
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-dd4ece7ac4ff> in <module>
# ----> 1 df.NaN
#
# c:\python36\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'NaN'
